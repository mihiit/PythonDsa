# %%
print("my name is mihit welcome to my python file")
# Out:
# my name is mihit welcome to my python file

# %%
#input two num and find the sum of the numbers
a= int(input("enter the number 1"))
b= int(input("enter the number 2"))
"sum="(a+b)
# Out:
# <>:4: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:4: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# enter the number 1 12
# enter number 2 13
# C:\Users\mihit nanda\AppData\Local\Temp\ipykernel_20268\3994162312.py:4: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   "sum="(a+b)
# C:\Users\mihit nanda\AppData\Local\Temp\ipykernel_20268\3994162312.py:4: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   "sum="(a+b)
# C:\Users\mihit nanda\AppData\Local\Temp\ipykernel_20268\3994162312.py:4: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   "sum="(a+b)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 a= int(input("enter the number 1"))
#       3 b= int(input("enter number 2"))
# ----> 4 "sum="(a+b)
#
# ...
