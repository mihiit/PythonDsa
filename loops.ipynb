# %%
# 27/01/2026 ( Concept of Loops and Advance Loops )
a = 5
b = 10
if a > b:
    print(a)
    if a < b:
        print(b)
if a > b:
    print(a)
elif a < b:
    print(b)
    
#3rd Case
if a > b:
    print(a)
elif a < b:
    print(b)
else:
    print("Nothing")
# Out:
# 10
# 10

# %%
for ch in "apple":
    print(ch, end = " ")
# Out:
# a p p l e

# %%
for ele in [2,4,6,8]:
    print(ele, end = " ")
# Out:
# 2 4 6 8

# %%
for n in range(5, 50, 10):
    print(n)
# Out:
# 5
# 15
# 25
# 35
# 45

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
i = 1
while i < 10:
    print(i)
    i += 2
# Out:
# 1
# 3
# 5
# 7
# 9
